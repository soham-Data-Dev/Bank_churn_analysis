# %%
import os
print(os.getcwd())
# Out:
# C:\Users\hp5cd\Desktop\bank-churn-analytics\notebooks

# %%
import pandas as pd 
df = pd.read_csv(r'C:\Users\hp5cd\Desktop\bank-churn-analytics\data\raw\Churn_Modelling (1).csv')

# %%
pip install pandas numpy matplotlib seaborn scikit-learn xgboost shap faker sqlalchemy streamlit
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 26.0.1 -> 26.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
df.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# ...

# %%
df.shape

df.info()

df.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        10000 non-null  int64
#  1   CustomerId       10000 non-null  int64
#  2   Surname          10000 non-null  object
#  3   CreditScore      10000 non-null  int64
#  4   Geography        10000 non-null  object
#  5   Gender           10000 non-null  object
#  6   Age              10000 non-null  int64
#  7   Tenure           10000 non-null  int64
#  8   Balance          10000 non-null  float64
#  9   NumOfProducts    10000 non-null  int64
#  10  HasCrCard        10000 non-null  int64
#  11  IsActiveMember   10000 non-null  int64
#  12  EstimatedSalary  10000 non-null  float64
#  13  Exited           10000 non-null  int64
# dtypes: float64(2), int64(9), object(3)
# memory usage: 1.1+ MB
# RowNumber          0
# CustomerId         0
# Surname            0
# ...

# %%
df.rename(columns={
    'CustomerId': 'customer_id',
    'Surname': 'surname',
    'CreditScore': 'credit_score',
    'Geography': 'country',
    'Gender': 'gender',
    'Age': 'age',
    'Tenure': 'tenure',
    'Balance': 'balance',
    'NumOfProducts': 'products_number',
    'IsActiveMember': 'active_member',
    'EstimatedSalary': 'estimated_salary',
    'Exited': 'churn'
}, inplace=True)

# %%
df.drop(
    ['RowNumber', 'customer_id', 'surname'],
    axis=1,
    inplace=True
)

# %%
df.to_csv(
    r"C:\Users\hp5cd\Desktop\bank-churn-analytics\data\processed\cleaned_bank_data.csv",
    index=False
)

# %%
import pandas as pd

customers = pd.read_csv(r'C:\Users\hp5cd\Desktop\bank-churn-analytics\data\raw\Churn_Modelling (1).csv')

transactions = pd.read_csv( r"C:\Users\hp5cd\Desktop\bank-churn-analytics\data\synthetic\transactions.csv")

# %%
customer_ids = transactions['customer_id'].unique()

# %%
customers['customer_id'] = customer_ids[:len(customers)]

# %%
customers.to_csv(
    r"C:\Users\hp5cd\Desktop\bank-churn-analytics\data\processed\customers_updated.csv",
    index=False
)

# %%
customers = pd.read_csv(r'C:\Users\hp5cd\Desktop\bank-churn-analytics\data\processed\customers_updated.csv')

# %%
customers = customers.rename(columns={

    'CustomerId': 'customer_id',
    'CreditScore': 'credit_score',
    'Geography': 'country',
    'NumOfProducts': 'products_number',
    'IsActiveMember': 'active_member',
    'EstimatedSalary': 'estimated_salary',
    'Exited': 'churn',
    'Gender': 'gender',
    'Age': 'age',
    'Tenure': 'tenure',
    'Balance': 'balance'

})

# %%
customers.to_csv(
     r"C:\Users\hp5cd\Desktop\bank-churn-analytics\data\processed\customers1_updated.csv",
    index=False
)
